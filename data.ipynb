# %%
import numpy as np
import nibabel as nib
import glob
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
TRAIN_DATASET_PATH = ".\BraTS20\BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData"
TRAIN_OUTPUT_IMAGE_PATH = '.\BraTS20\BraTS2020_TrainingData\input_data_4channels\\train\images\\'
TRAIN_OUTPUT_MASK_PATH = '.\BraTS20\BraTS2020_TrainingData\input_data_4channels\\train\masks\\'
VAL_OUTPUT_IMAGE_PATH = '.\BraTS20\BraTS2020_TrainingData\input_data_4channels\\val\images\\'
VAL_OUTPUT_MASK_PATH = '.\BraTS20\BraTS2020_TrainingData\input_data_4channels\\val\masks\\'

# %%
import os
# Ensure output directories exist
os.makedirs(TRAIN_OUTPUT_IMAGE_PATH, exist_ok=True)
os.makedirs(TRAIN_OUTPUT_MASK_PATH, exist_ok=True)
os.makedirs(VAL_OUTPUT_IMAGE_PATH, exist_ok=True)
os.makedirs(VAL_OUTPUT_MASK_PATH, exist_ok=True)

# %%
# Define lists of files for each modality and the segmentation mask
t1_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*t1.nii'))
t2_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*t2.nii'))
t1ce_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*t1ce.nii'))
flair_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*flair.nii'))
mask_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*seg.nii'))  # remane the mask in  the training dataset 355 (Seg -> seg)

# %%
print(len(t1_list ),len(t1ce_list), len(t2_list ), len(flair_list ), len(mask_list ))
# Out:
# 369 369 369 369 369

# %%
# Define crop boundaries
CROP_BOUNDARIES = (slice(56, 184), slice(56, 184), slice(13, 141))

# %% [markdown]
# **Why Crop?**
# - **Focus on Relevant Areas:** By cropping, you ensure that the model processes only the most relevant portions of the image, which can improve training efficiency.
# - **Memory and Computation:** 3D medical images are large and require significant computational resources. Cropping reduces the size of the data, making it more manageable for GPU memory and speeding up training.
# - **Patch Size Compatibility:** Many deep learning architectures, especially those dealing with 3D data, require input sizes divisible by a specific number (like 64 in this code). Cropping ensures the volume fits this requirement.
#
# **Drawbacks of Cropping:**
# - **Risk of Losing Important Information:** If the cropping is too aggressive or poorly designed, important parts of the image (like a tumor) could be excluded, which could negatively impact the model's performance.
# - **Assumption of Consistency:** Cropping assumes that the region of interest (ROI) is consistently located within the same region across all images. This might not hold true for all patients or images, potentially leading to information loss.

# %%
# Function to load and scale a NIfTI image
def load_and_scale_image(filepath):
    image = nib.load(filepath).get_fdata()
    scaled_image = scaler.fit_transform(image.reshape(-1, image.shape[-1])).reshape(image.shape)
    return scaled_image

# %%
import torch
from colorama import Fore, Style

def save_as_torch_tensor(tensor, path):
    torch.save(tensor, path)

# Process and save each image-mask pair as Torch tensors
for img_idx in range(len(t1_list)):
    print(Fore.CYAN + f"Processing image and mask number: {img_idx}" + Style.RESET_ALL)
    # Loading images
    image_t1 = load_and_scale_image(t1_list[img_idx])
    image_t2 = load_and_scale_image(t2_list[img_idx])
    image_t1ce = load_and_scale_image(t1ce_list[img_idx])
    image_flair = load_and_scale_image(flair_list[img_idx])

    # Check if images are loaded correctly
    print(f"Loaded images with shapes: {image_t1.shape}, {image_t2.shape}, {image_t1ce.shape}, {image_flair.shape}")

    # Load mask
    mask = nib.load(mask_list[img_idx]).get_fdata().astype(np.uint8)
    print(f"Loaded mask with shape: {mask.shape}" )

    # Ensure correct reassignment in mask
    mask[mask == 4] = 3

    # Combine images
    combined_image = np.stack([image_t1, image_flair, image_t1ce, image_t2], axis=-1)
    print(f"Combined image shape: {combined_image.shape}")

    # Crop
    cropped_image = combined_image[CROP_BOUNDARIES]
    cropped_mask = mask[CROP_BOUNDARIES]
    print(f"Cropped image shape: {cropped_image.shape}, Cropped mask shape: {cropped_mask.shape}")

    # Check non-zero ratio
    _, counts = np.unique(cropped_mask, return_counts=True)
    non_zero_ratio = 1 - (counts[0] / counts.sum())
    print(f"Non-zero ratio: {non_zero_ratio}")

    if non_zero_ratio > 0.01:
        # One-hot encode mask
        categorical_mask = to_categorical(cropped_mask, num_classes=4)
        print(f"Categorical mask shape: {categorical_mask.shape}")

        # Convert to Torch tensors and permute to appropriate format 
        torch_image = torch.from_numpy(cropped_image).permute(3, 0, 1, 2).float()
        torch_mask = torch.from_numpy(categorical_mask).permute(3, 0, 1, 2).float()
        
        # Save the tensors
        if img_idx < len(t2_list) * 0.8:
            save_as_torch_tensor(torch_image, f'{TRAIN_OUTPUT_IMAGE_PATH}image_{img_idx}.pt')
            save_as_torch_tensor(torch_mask, f'{TRAIN_OUTPUT_MASK_PATH}mask_{img_idx}.pt')
        else:
            save_as_torch_tensor(torch_image, f'{VAL_OUTPUT_IMAGE_PATH}image_{img_idx}.pt')
            save_as_torch_tensor(torch_mask, f'{VAL_OUTPUT_MASK_PATH}mask_{img_idx}.pt')
        print(Fore.GREEN + f"Saved image and mask for index {img_idx}." + Style.RESET_ALL)
    else:
        print(Fore.RED + f"Skipped image {img_idx} due to low non-zero ratio." + Style.RESET_ALL)
# Out:
# Processing image and mask number: 0
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.10062837600708008
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 0.
# Processing image and mask number: 1
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.031950950622558594
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 1.
# Processing image and mask number: 2
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.014213085174560547
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 2.
# Processing image and mask number: 3
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.045760154724121094
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 3.
# Processing image and mask number: 4
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.009261608123779297
# Skipped image 4 due to low non-zero ratio.
# Processing image and mask number: 5
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.06627607345581055
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 5.
# Processing image and mask number: 6
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.01891469955444336
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 6.
# Processing image and mask number: 7
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.01594686508178711
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 7.
# Processing image and mask number: 8
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.08273983001708984
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 8.
# Processing image and mask number: 9
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.021076679229736328
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 9.
# Processing image and mask number: 10
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.02525615692138672
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 10.
# Processing image and mask number: 11
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.015116214752197266
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 11.
# Processing image and mask number: 12
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.02209615707397461
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 12.
# Processing image and mask number: 13
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.037972450256347656
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 13.
# Processing image and mask number: 14
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.05974149703979492
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 14.
# Processing image and mask number: 15
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.06057548522949219
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 15.
# Processing image and mask number: 16
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.047312259674072266
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 16.
# Processing image and mask number: 17
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.02089548110961914
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 17.
# Processing image and mask number: 18
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.020884037017822266
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 18.
# Processing image and mask number: 19
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.0823354721069336
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 19.
# Processing image and mask number: 20
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.01757526397705078
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 20.
# Processing image and mask number: 21
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03248119354248047
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 21.
# Processing image and mask number: 22
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.01960897445678711
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 22.
# Processing image and mask number: 23
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04044532775878906
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 23.
# Processing image and mask number: 24
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03501749038696289
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 24.
# Processing image and mask number: 25
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.08512639999389648
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 25.
# Processing image and mask number: 26
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.031780242919921875
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 26.
# Processing image and mask number: 27
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.009764671325683594
# Skipped image 27 due to low non-zero ratio.
# Processing image and mask number: 28
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.029731273651123047
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 28.
# Processing image and mask number: 29
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.047368526458740234
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 29.
# Processing image and mask number: 30
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.038857460021972656
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 30.
# Processing image and mask number: 31
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.012636184692382812
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 31.
# Processing image and mask number: 32
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.05846977233886719
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 32.
# Processing image and mask number: 33
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.043665409088134766
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 33.
# Processing image and mask number: 34
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03627967834472656
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 34.
# Processing image and mask number: 35
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.007068634033203125
# Skipped image 35 due to low non-zero ratio.
# Processing image and mask number: 36
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.08803415298461914
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 36.
# Processing image and mask number: 37
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04322528839111328
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 37.
# Processing image and mask number: 38
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.02472543716430664
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 38.
# Processing image and mask number: 39
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.06412220001220703
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 39.
# Processing image and mask number: 40
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.033681392669677734
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 40.
# Processing image and mask number: 41
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.032778263092041016
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 41.
# Processing image and mask number: 42
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.017847537994384766
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 42.
# Processing image and mask number: 43
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.009131431579589844
# Skipped image 43 due to low non-zero ratio.
# Processing image and mask number: 44
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04511737823486328
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 44.
# Processing image and mask number: 45
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.01732921600341797
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 45.
# Processing image and mask number: 46
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.06326675415039062
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 46.
# Processing image and mask number: 47
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.013942241668701172
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 47.
# Processing image and mask number: 48
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.02625131607055664
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 48.
# Processing image and mask number: 49
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.037337303161621094
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 49.
# Processing image and mask number: 50
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.057969093322753906
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 50.
# Processing image and mask number: 51
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.01904773712158203
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 51.
# Processing image and mask number: 52
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.06951618194580078
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 52.
# Processing image and mask number: 53
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.038144588470458984
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 53.
# Processing image and mask number: 54
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.05358600616455078
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 54.
# Processing image and mask number: 55
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.024731159210205078
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 55.
# Processing image and mask number: 56
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04309225082397461
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 56.
# Processing image and mask number: 57
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04354572296142578
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 57.
# Processing image and mask number: 58
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.012358665466308594
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 58.
# Processing image and mask number: 59
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04160261154174805
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 59.
# Processing image and mask number: 60
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.009953975677490234
# Skipped image 60 due to low non-zero ratio.
# Processing image and mask number: 61
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.06776142120361328
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 61.
# Processing image and mask number: 62
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.006234645843505859
# Skipped image 62 due to low non-zero ratio.
# Processing image and mask number: 63
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04568815231323242
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 63.
# Processing image and mask number: 64
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.011876106262207031
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 64.
# Processing image and mask number: 65
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.02823019027709961
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 65.
# Processing image and mask number: 66
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.0523991584777832
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 66.
# Processing image and mask number: 67
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.027435302734375
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 67.
# Processing image and mask number: 68
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.07321405410766602
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 68.
# Processing image and mask number: 69
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.02752208709716797
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 69.
# Processing image and mask number: 70
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.07227039337158203
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 70.
# Processing image and mask number: 71
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03849935531616211
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 71.
# Processing image and mask number: 72
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.021228313446044922
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 72.
# Processing image and mask number: 73
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.029632568359375
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 73.
# Processing image and mask number: 74
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.08785820007324219
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 74.
# Processing image and mask number: 75
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.018949031829833984
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 75.
# Processing image and mask number: 76
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.023929119110107422
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 76.
# Processing image and mask number: 77
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.018518447875976562
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 77.
# Processing image and mask number: 78
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.0034737586975097656
# Skipped image 78 due to low non-zero ratio.
# Processing image and mask number: 79
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.018266677856445312
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 79.
# Processing image and mask number: 80
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.015035629272460938
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 80.
# Processing image and mask number: 81
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.004816532135009766
# Skipped image 81 due to low non-zero ratio.
# Processing image and mask number: 82
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03512239456176758
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 82.
# Processing image and mask number: 83
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.023089885711669922
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 83.
# Processing image and mask number: 84
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.014678955078125
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 84.
# Processing image and mask number: 85
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.008098602294921875
# Skipped image 85 due to low non-zero ratio.
# Processing image and mask number: 86
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.012555122375488281
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 86.
# Processing image and mask number: 87
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.014616966247558594
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 87.
# Processing image and mask number: 88
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.061626434326171875
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 88.
# Processing image and mask number: 89
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.015286922454833984
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 89.
# Processing image and mask number: 90
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.07106208801269531
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 90.
# Processing image and mask number: 91
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.02787494659423828
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 91.
# Processing image and mask number: 92
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04648637771606445
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 92.
# Processing image and mask number: 93
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.010456562042236328
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 93.
# Processing image and mask number: 94
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.049480438232421875
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 94.
# Processing image and mask number: 95
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03146791458129883
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 95.
# Processing image and mask number: 96
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03779125213623047
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 96.
# Processing image and mask number: 97
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.06843852996826172
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 97.
# Processing image and mask number: 98
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.003582477569580078
# Skipped image 98 due to low non-zero ratio.
# Processing image and mask number: 99
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.06297492980957031
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 99.
# Processing image and mask number: 100
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03421354293823242
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 100.
# Processing image and mask number: 101
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.011512279510498047
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 101.
# Processing image and mask number: 102
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.018471240997314453
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 102.
# Processing image and mask number: 103
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.07972955703735352
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 103.
# Processing image and mask number: 104
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.0119171142578125
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 104.
# Processing image and mask number: 105
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.05128145217895508
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 105.
# Processing image and mask number: 106
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.016360759735107422
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 106.
# Processing image and mask number: 107
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.008531570434570312
# Skipped image 107 due to low non-zero ratio.
# Processing image and mask number: 108
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04751300811767578
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 108.
# Processing image and mask number: 109
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.007515907287597656
# Skipped image 109 due to low non-zero ratio.
# Processing image and mask number: 110
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.018129348754882812
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 110.
# Processing image and mask number: 111
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.07528257369995117
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 111.
# Processing image and mask number: 112
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.05941152572631836
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 112.
# Processing image and mask number: 113
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.049259185791015625
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 113.
# Processing image and mask number: 114
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04320478439331055
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 114.
# Processing image and mask number: 115
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04173994064331055
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 115.
# Processing image and mask number: 116
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03725719451904297
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 116.
# Processing image and mask number: 117
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.02501678466796875
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 117.
# Processing image and mask number: 118
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.015141010284423828
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 118.
# Processing image and mask number: 119
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.05895233154296875
# Categorical mask shape: (128, 128, 128, 4)
# ...
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.025570392608642578
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 329.
# Processing image and mask number: 330
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.023774147033691406
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 330.
# Processing image and mask number: 331
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.02691507339477539
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 331.
# Processing image and mask number: 332
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.07639455795288086
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 332.
# Processing image and mask number: 333
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.07188081741333008
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 333.
# Processing image and mask number: 334
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.06500911712646484
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 334.
# Processing image and mask number: 335
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.033410072326660156
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 335.
# Processing image and mask number: 336
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04596233367919922
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 336.
# Processing image and mask number: 337
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.06602287292480469
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 337.
# Processing image and mask number: 338
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.0678868293762207
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 338.
# Processing image and mask number: 339
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03706932067871094
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 339.
# Processing image and mask number: 340
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.005946159362792969
# Skipped image 340 due to low non-zero ratio.
# Processing image and mask number: 341
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.07162237167358398
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 341.
# Processing image and mask number: 342
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.07315683364868164
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 342.
# Processing image and mask number: 343
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03760099411010742
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 343.
# Processing image and mask number: 344
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04150819778442383
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 344.
# Processing image and mask number: 345
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03743886947631836
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 345.
# Processing image and mask number: 346
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.053221702575683594
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 346.
# Processing image and mask number: 347
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04057455062866211
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 347.
# Processing image and mask number: 348
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.07418394088745117
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 348.
# Processing image and mask number: 349
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04693317413330078
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 349.
# Processing image and mask number: 350
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04720354080200195
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 350.
# Processing image and mask number: 351
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.017855167388916016
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 351.
# Processing image and mask number: 352
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.017810344696044922
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 352.
# Processing image and mask number: 353
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.0786900520324707
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 353.
# Processing image and mask number: 354
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.06581449508666992
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 354.
# Processing image and mask number: 355
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.013981342315673828
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 355.
# Processing image and mask number: 356
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.028307437896728516
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 356.
# Processing image and mask number: 357
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.05116701126098633
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 357.
# Processing image and mask number: 358
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03751230239868164
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 358.
# Processing image and mask number: 359
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04697418212890625
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 359.
# Processing image and mask number: 360
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.027235984802246094
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 360.
# Processing image and mask number: 361
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.07552194595336914
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 361.
# Processing image and mask number: 362
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.05739784240722656
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 362.
# Processing image and mask number: 363
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.04669666290283203
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 363.
# Processing image and mask number: 364
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.0699925422668457
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 364.
# Processing image and mask number: 365
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.01226663589477539
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 365.
# Processing image and mask number: 366
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.05736875534057617
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 366.
# Processing image and mask number: 367
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.03925037384033203
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 367.
# Processing image and mask number: 368
# Loaded images with shapes: (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)
# Loaded mask with shape: (240, 240, 155)
# Combined image shape: (240, 240, 155, 4)
# Cropped image shape: (128, 128, 128, 4), Cropped mask shape: (128, 128, 128)
# Non-zero ratio: 0.10072517395019531
# Categorical mask shape: (128, 128, 128, 4)
# Saved image and mask for index 368.
