# %%
import numpy as np
import nibabel as nib
import glob
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
TRAIN_DATASET_PATH = ".\BraTS20\BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData"
TRAIN_OUTPUT_IMAGE_PATH = '.\BraTS20\BraTS2020_TrainingData\input_data_4channels\images\\'
TRAIN_OUTPUT_MASK_PATH = '.\BraTS20\BraTS2020_TrainingData\input_data_4channels\masks\\'
VAL_OUTPUT_IMAGE_PATH = '.\BraTS20\BraTS2020_TrainingData\input_data_4channels\images\\'
VAL_OUTPUT_MASK_PATH = '.\BraTS20\BraTS2020_TrainingData\input_data_4channels\masks\\'

# %%
import os
# Ensure output directories exist
os.makedirs(TRAIN_OUTPUT_IMAGE_PATH, exist_ok=True)
os.makedirs(TRAIN_OUTPUT_MASK_PATH, exist_ok=True)
os.makedirs(VAL_OUTPUT_IMAGE_PATH, exist_ok=True)
os.makedirs(VAL_OUTPUT_MASK_PATH, exist_ok=True)

# %%
# Define lists of files for each modality and the segmentation mask
t1_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*t1.nii'))
t2_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*t2.nii'))
t1ce_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*t1ce.nii'))
flair_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*flair.nii'))
mask_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*seg.nii'))  # remane the mask in  the training dataset 355 (Seg -> seg)

# %%
print(len(t1_list ),len(t1ce_list), len(t2_list ), len(flair_list ), len(mask_list ))
# Out:
# 369 369 369 369 369

# %%
# Define crop boundaries
CROP_BOUNDARIES = (slice(56, 184), slice(56, 184), slice(13, 141))

# %% [markdown]
# **Why Crop?**
# - **Focus on Relevant Areas:** By cropping, you ensure that the model processes only the most relevant portions of the image, which can improve training efficiency.
# - **Memory and Computation:** 3D medical images are large and require significant computational resources. Cropping reduces the size of the data, making it more manageable for GPU memory and speeding up training.
# - **Patch Size Compatibility:** Many deep learning architectures, especially those dealing with 3D data, require input sizes divisible by a specific number (like 64 in this code). Cropping ensures the volume fits this requirement.
#
# **Drawbacks of Cropping:**
# - **Risk of Losing Important Information:** If the cropping is too aggressive or poorly designed, important parts of the image (like a tumor) could be excluded, which could negatively impact the model's performance.
# - **Assumption of Consistency:** Cropping assumes that the region of interest (ROI) is consistently located within the same region across all images. This might not hold true for all patients or images, potentially leading to information loss.

# %%
# Function to load and scale a NIfTI image
def load_and_scale_image(filepath):
    image = nib.load(filepath).get_fdata()
    scaled_image = scaler.fit_transform(image.reshape(-1, image.shape[-1])).reshape(image.shape)
    return scaled_image

# %%
import torch


def save_as_torch_tensor(tensor, path):
    torch.save(tensor, path)

# Process and save each image-mask pair as Torch tensors
for img_idx in range(len(t1_list)):
    print(f"Processing image and mask number: {img_idx}")

    image_t1 = load_and_scale_image(t1_list[img_idx])
    image_t2 = load_and_scale_image(t2_list[img_idx])
    image_t1ce = load_and_scale_image(t1ce_list[img_idx])
    image_flair = load_and_scale_image(flair_list[img_idx])

    mask = nib.load(mask_list[img_idx]).get_fdata().astype(np.uint8)
    mask[mask == 4] = 3  # Reassign mask values 4 to 3

    # Combine the images into a multi-channel array
    combined_image = np.stack([image_t1, image_flair, image_t1ce, image_t2], axis=-1)

    # Crop the combined image and mask
    cropped_image = combined_image[CROP_BOUNDARIES]
    cropped_mask = mask[CROP_BOUNDARIES]

    # Check if the mask contains at least 1% non-zero values
    _, counts = np.unique(cropped_mask, return_counts=True)
    non_zero_ratio = 1 - (counts[0] / counts.sum())
    
    if non_zero_ratio > 0.01:  # At least 1% useful volume
        # One-hot encode the mask
        categorical_mask = to_categorical(cropped_mask, num_classes=4)

        # Convert to Torch tensors
        torch_image = torch.from_numpy(cropped_image).float()
        torch_mask = torch.from_numpy(categorical_mask).float()

        # Save the processed image and mask as Torch tensors

        if img_idx < len(t2_list) * 0.8:  # Train split
            save_as_torch_tensor(torch_image, f'{TRAIN_OUTPUT_IMAGE_PATH}image_{img_idx}.pt')
            save_as_torch_tensor(torch_mask, f'{TRAIN_OUTPUT_MASK_PATH}mask_{img_idx}.pt')
            print("Saved image and mask.")
        else:  # Validation split
            save_as_torch_tensor(torch_image, f'{VAL_OUTPUT_IMAGE_PATH}image_{img_idx}.pt')
            save_as_torch_tensor(torch_mask, f'{VAL_OUTPUT_MASK_PATH}mask_{img_idx}.pt')
            print("Saved image and mask.")
    else:
        print("Skipped due to low non-zero ratio.")

print("Preprocessing complete.")
# Out:
# Processing image and mask number: 0
# Saved image and mask.
# Processing image and mask number: 1
# Saved image and mask.
# Processing image and mask number: 2
# Saved image and mask.
# Processing image and mask number: 3
# Saved image and mask.
# Processing image and mask number: 4
# Skipped due to low non-zero ratio.
# Processing image and mask number: 5
# Saved image and mask.
# Processing image and mask number: 6
# Saved image and mask.
# Processing image and mask number: 7
# Saved image and mask.
# Processing image and mask number: 8
# Saved image and mask.
# Processing image and mask number: 9
# Saved image and mask.
# Processing image and mask number: 10
# Saved image and mask.
# Processing image and mask number: 11
# Saved image and mask.
# Processing image and mask number: 12
# Saved image and mask.
# Processing image and mask number: 13
# Saved image and mask.
# Processing image and mask number: 14
# Saved image and mask.
# Processing image and mask number: 15
# Saved image and mask.
# Processing image and mask number: 16
# Saved image and mask.
# Processing image and mask number: 17
# Saved image and mask.
# Processing image and mask number: 18
# Saved image and mask.
# Processing image and mask number: 19
# Saved image and mask.
# Processing image and mask number: 20
# Saved image and mask.
# Processing image and mask number: 21
# Saved image and mask.
# Processing image and mask number: 22
# Saved image and mask.
# Processing image and mask number: 23
# Saved image and mask.
# Processing image and mask number: 24
# Saved image and mask.
# Processing image and mask number: 25
# Saved image and mask.
# Processing image and mask number: 26
# Saved image and mask.
# Processing image and mask number: 27
# Skipped due to low non-zero ratio.
# Processing image and mask number: 28
# Saved image and mask.
# Processing image and mask number: 29
# Saved image and mask.
# Processing image and mask number: 30
# Saved image and mask.
# Processing image and mask number: 31
# Saved image and mask.
# Processing image and mask number: 32
# Saved image and mask.
# Processing image and mask number: 33
# Saved image and mask.
# Processing image and mask number: 34
# Saved image and mask.
# Processing image and mask number: 35
# Skipped due to low non-zero ratio.
# Processing image and mask number: 36
# Saved image and mask.
# Processing image and mask number: 37
# Saved image and mask.
# Processing image and mask number: 38
# Saved image and mask.
# Processing image and mask number: 39
# Saved image and mask.
# Processing image and mask number: 40
# Saved image and mask.
# Processing image and mask number: 41
# Saved image and mask.
# Processing image and mask number: 42
# Saved image and mask.
# Processing image and mask number: 43
# Skipped due to low non-zero ratio.
# Processing image and mask number: 44
# Saved image and mask.
# Processing image and mask number: 45
# Saved image and mask.
# Processing image and mask number: 46
# Saved image and mask.
# Processing image and mask number: 47
# Saved image and mask.
# Processing image and mask number: 48
# Saved image and mask.
# Processing image and mask number: 49
# Saved image and mask.
# Processing image and mask number: 50
# Saved image and mask.
# Processing image and mask number: 51
# Saved image and mask.
# Processing image and mask number: 52
# Saved image and mask.
# Processing image and mask number: 53
# Saved image and mask.
# Processing image and mask number: 54
# Saved image and mask.
# Processing image and mask number: 55
# Saved image and mask.
# Processing image and mask number: 56
# Saved image and mask.
# Processing image and mask number: 57
# Saved image and mask.
# Processing image and mask number: 58
# Saved image and mask.
# Processing image and mask number: 59
# Saved image and mask.
# Processing image and mask number: 60
# Skipped due to low non-zero ratio.
# Processing image and mask number: 61
# Saved image and mask.
# Processing image and mask number: 62
# Skipped due to low non-zero ratio.
# Processing image and mask number: 63
# Saved image and mask.
# Processing image and mask number: 64
# Saved image and mask.
# Processing image and mask number: 65
# Saved image and mask.
# Processing image and mask number: 66
# Saved image and mask.
# Processing image and mask number: 67
# Saved image and mask.
# Processing image and mask number: 68
# Saved image and mask.
# Processing image and mask number: 69
# Saved image and mask.
# Processing image and mask number: 70
# Saved image and mask.
# Processing image and mask number: 71
# Saved image and mask.
# Processing image and mask number: 72
# Saved image and mask.
# Processing image and mask number: 73
# Saved image and mask.
# Processing image and mask number: 74
# Saved image and mask.
# Processing image and mask number: 75
# Saved image and mask.
# Processing image and mask number: 76
# Saved image and mask.
# Processing image and mask number: 77
# Saved image and mask.
# Processing image and mask number: 78
# Skipped due to low non-zero ratio.
# Processing image and mask number: 79
# Saved image and mask.
# Processing image and mask number: 80
# Saved image and mask.
# Processing image and mask number: 81
# Skipped due to low non-zero ratio.
# Processing image and mask number: 82
# Saved image and mask.
# Processing image and mask number: 83
# Saved image and mask.
# Processing image and mask number: 84
# Saved image and mask.
# Processing image and mask number: 85
# Skipped due to low non-zero ratio.
# Processing image and mask number: 86
# Saved image and mask.
# Processing image and mask number: 87
# Saved image and mask.
# Processing image and mask number: 88
# Saved image and mask.
# Processing image and mask number: 89
# Saved image and mask.
# Processing image and mask number: 90
# Saved image and mask.
# Processing image and mask number: 91
# Saved image and mask.
# Processing image and mask number: 92
# Saved image and mask.
# Processing image and mask number: 93
# Saved image and mask.
# Processing image and mask number: 94
# Saved image and mask.
# Processing image and mask number: 95
# Saved image and mask.
# Processing image and mask number: 96
# Saved image and mask.
# Processing image and mask number: 97
# Saved image and mask.
# Processing image and mask number: 98
# Skipped due to low non-zero ratio.
# Processing image and mask number: 99
# Saved image and mask.
# Processing image and mask number: 100
# Saved image and mask.
# Processing image and mask number: 101
# Saved image and mask.
# Processing image and mask number: 102
# Saved image and mask.
# Processing image and mask number: 103
# Saved image and mask.
# Processing image and mask number: 104
# Saved image and mask.
# Processing image and mask number: 105
# Saved image and mask.
# Processing image and mask number: 106
# Saved image and mask.
# Processing image and mask number: 107
# Skipped due to low non-zero ratio.
# Processing image and mask number: 108
# Saved image and mask.
# Processing image and mask number: 109
# Skipped due to low non-zero ratio.
# Processing image and mask number: 110
# Saved image and mask.
# Processing image and mask number: 111
# Saved image and mask.
# Processing image and mask number: 112
# Saved image and mask.
# Processing image and mask number: 113
# Saved image and mask.
# Processing image and mask number: 114
# Saved image and mask.
# Processing image and mask number: 115
# Saved image and mask.
# Processing image and mask number: 116
# Saved image and mask.
# Processing image and mask number: 117
# Saved image and mask.
# Processing image and mask number: 118
# Saved image and mask.
# Processing image and mask number: 119
# Saved image and mask.
# Processing image and mask number: 120
# Saved image and mask.
# Processing image and mask number: 121
# Skipped due to low non-zero ratio.
# Processing image and mask number: 122
# Saved image and mask.
# Processing image and mask number: 123
# Saved image and mask.
# Processing image and mask number: 124
# Saved image and mask.
# Processing image and mask number: 125
# Saved image and mask.
# Processing image and mask number: 126
# Saved image and mask.
# Processing image and mask number: 127
# Saved image and mask.
# Processing image and mask number: 128
# Saved image and mask.
# Processing image and mask number: 129
# Saved image and mask.
# Processing image and mask number: 130
# Saved image and mask.
# Processing image and mask number: 131
# Saved image and mask.
# Processing image and mask number: 132
# Saved image and mask.
# Processing image and mask number: 133
# Saved image and mask.
# Processing image and mask number: 134
# Saved image and mask.
# Processing image and mask number: 135
# Saved image and mask.
# Processing image and mask number: 136
# Saved image and mask.
# Processing image and mask number: 137
# Saved image and mask.
# Processing image and mask number: 138
# Skipped due to low non-zero ratio.
# Processing image and mask number: 139
# Saved image and mask.
# Processing image and mask number: 140
# Saved image and mask.
# Processing image and mask number: 141
# Skipped due to low non-zero ratio.
# Processing image and mask number: 142
# Saved image and mask.
# Processing image and mask number: 143
# Saved image and mask.
# Processing image and mask number: 144
# Saved image and mask.
# Processing image and mask number: 145
# Saved image and mask.
# Processing image and mask number: 146
# Saved image and mask.
# Processing image and mask number: 147
# Saved image and mask.
# Processing image and mask number: 148
# Saved image and mask.
# Processing image and mask number: 149
# Saved image and mask.
# Processing image and mask number: 150
# Saved image and mask.
# Processing image and mask number: 151
# Saved image and mask.
# Processing image and mask number: 152
# Saved image and mask.
# Processing image and mask number: 153
# Saved image and mask.
# Processing image and mask number: 154
# Saved image and mask.
# Processing image and mask number: 155
# Saved image and mask.
# Processing image and mask number: 156
# Saved image and mask.
# Processing image and mask number: 157
# Saved image and mask.
# Processing image and mask number: 158
# Saved image and mask.
# Processing image and mask number: 159
# Saved image and mask.
# Processing image and mask number: 160
# Saved image and mask.
# Processing image and mask number: 161
# Saved image and mask.
# Processing image and mask number: 162
# Saved image and mask.
# Processing image and mask number: 163
# Saved image and mask.
# Processing image and mask number: 164
# Saved image and mask.
# Processing image and mask number: 165
# Saved image and mask.
# Processing image and mask number: 166
# Saved image and mask.
# Processing image and mask number: 167
# Saved image and mask.
# Processing image and mask number: 168
# Saved image and mask.
# Processing image and mask number: 169
# Saved image and mask.
# Processing image and mask number: 170
# Saved image and mask.
# Processing image and mask number: 171
# Saved image and mask.
# Processing image and mask number: 172
# Saved image and mask.
# Processing image and mask number: 173
# Saved image and mask.
# Processing image and mask number: 174
# Saved image and mask.
# Processing image and mask number: 175
# Saved image and mask.
# Processing image and mask number: 176
# Skipped due to low non-zero ratio.
# Processing image and mask number: 177
# Saved image and mask.
# Processing image and mask number: 178
# Saved image and mask.
# Processing image and mask number: 179
# Saved image and mask.
# Processing image and mask number: 180
# Saved image and mask.
# Processing image and mask number: 181
# Saved image and mask.
# Processing image and mask number: 182
# Saved image and mask.
# Processing image and mask number: 183
# Saved image and mask.
# Processing image and mask number: 184
# Saved image and mask.
# Processing image and mask number: 185
# Saved image and mask.
# Processing image and mask number: 186
# Saved image and mask.
# Processing image and mask number: 187
# Saved image and mask.
# Processing image and mask number: 188
# Saved image and mask.
# Processing image and mask number: 189
# Saved image and mask.
# Processing image and mask number: 190
# Saved image and mask.
# Processing image and mask number: 191
# Saved image and mask.
# Processing image and mask number: 192
# Saved image and mask.
# Processing image and mask number: 193
# Saved image and mask.
# Processing image and mask number: 194
# Saved image and mask.
# Processing image and mask number: 195
# Saved image and mask.
# Processing image and mask number: 196
# Saved image and mask.
# Processing image and mask number: 197
# Saved image and mask.
# Processing image and mask number: 198
# Saved image and mask.
# Processing image and mask number: 199
# Saved image and mask.
# Processing image and mask number: 200
# Saved image and mask.
# Processing image and mask number: 201
# Saved image and mask.
# Processing image and mask number: 202
# Saved image and mask.
# Processing image and mask number: 203
# Skipped due to low non-zero ratio.
# Processing image and mask number: 204
# Saved image and mask.
# Processing image and mask number: 205
# Saved image and mask.
# Processing image and mask number: 206
# Saved image and mask.
# Processing image and mask number: 207
# Saved image and mask.
# Processing image and mask number: 208
# Saved image and mask.
# Processing image and mask number: 209
# Saved image and mask.
# Processing image and mask number: 210
# Saved image and mask.
# Processing image and mask number: 211
# Saved image and mask.
# Processing image and mask number: 212
# Saved image and mask.
# Processing image and mask number: 213
# Saved image and mask.
# Processing image and mask number: 214
# Saved image and mask.
# Processing image and mask number: 215
# Saved image and mask.
# Processing image and mask number: 216
# Skipped due to low non-zero ratio.
# Processing image and mask number: 217
# Saved image and mask.
# Processing image and mask number: 218
# Saved image and mask.
# Processing image and mask number: 219
# Saved image and mask.
# Processing image and mask number: 220
# Saved image and mask.
# Processing image and mask number: 221
# Saved image and mask.
# Processing image and mask number: 222
# Saved image and mask.
# Processing image and mask number: 223
# Saved image and mask.
# Processing image and mask number: 224
# Saved image and mask.
# Processing image and mask number: 225
# Saved image and mask.
# Processing image and mask number: 226
# Saved image and mask.
# Processing image and mask number: 227
# Saved image and mask.
# Processing image and mask number: 228
# Saved image and mask.
# Processing image and mask number: 229
# Saved image and mask.
# Processing image and mask number: 230
# Saved image and mask.
# Processing image and mask number: 231
# Saved image and mask.
# Processing image and mask number: 232
# Skipped due to low non-zero ratio.
# Processing image and mask number: 233
# Saved image and mask.
# Processing image and mask number: 234
# Saved image and mask.
# Processing image and mask number: 235
# Saved image and mask.
# Processing image and mask number: 236
# Saved image and mask.
# Processing image and mask number: 237
# Saved image and mask.
# Processing image and mask number: 238
# Saved image and mask.
# Processing image and mask number: 239
# Saved image and mask.
# Processing image and mask number: 240
# Saved image and mask.
# Processing image and mask number: 241
# Saved image and mask.
# Processing image and mask number: 242
# Saved image and mask.
# Processing image and mask number: 243
# Saved image and mask.
# Processing image and mask number: 244
# Saved image and mask.
# Processing image and mask number: 245
# Saved image and mask.
# Processing image and mask number: 246
# Saved image and mask.
# Processing image and mask number: 247
# Saved image and mask.
# Processing image and mask number: 248
# Saved image and mask.
# Processing image and mask number: 249
# Saved image and mask.
# Processing image and mask number: 250
# Saved image and mask.
# Processing image and mask number: 251
# Saved image and mask.
# Processing image and mask number: 252
# Saved image and mask.
# Processing image and mask number: 253
# Saved image and mask.
# Processing image and mask number: 254
# Saved image and mask.
# Processing image and mask number: 255
# Saved image and mask.
# Processing image and mask number: 256
# Saved image and mask.
# Processing image and mask number: 257
# Saved image and mask.
# Processing image and mask number: 258
# Saved image and mask.
# Processing image and mask number: 259
# Saved image and mask.
# Processing image and mask number: 260
# Saved image and mask.
# Processing image and mask number: 261
# Saved image and mask.
# Processing image and mask number: 262
# Saved image and mask.
# Processing image and mask number: 263
# Saved image and mask.
# Processing image and mask number: 264
# Saved image and mask.
# Processing image and mask number: 265
# Saved image and mask.
# Processing image and mask number: 266
# Saved image and mask.
# Processing image and mask number: 267
# Skipped due to low non-zero ratio.
# Processing image and mask number: 268
# Saved image and mask.
# Processing image and mask number: 269
# Saved image and mask.
# Processing image and mask number: 270
# Saved image and mask.
# Processing image and mask number: 271
# Saved image and mask.
# Processing image and mask number: 272
# Saved image and mask.
# Processing image and mask number: 273
# Saved image and mask.
# Processing image and mask number: 274
# Saved image and mask.
# Processing image and mask number: 275
# Saved image and mask.
# Processing image and mask number: 276
# Skipped due to low non-zero ratio.
# Processing image and mask number: 277
# Saved image and mask.
# Processing image and mask number: 278
# Saved image and mask.
# Processing image and mask number: 279
# Saved image and mask.
# Processing image and mask number: 280
# Saved image and mask.
# Processing image and mask number: 281
# Saved image and mask.
# Processing image and mask number: 282
# Saved image and mask.
# Processing image and mask number: 283
# Saved image and mask.
# Processing image and mask number: 284
# Saved image and mask.
# Processing image and mask number: 285
# Saved image and mask.
# Processing image and mask number: 286
# Saved image and mask.
# Processing image and mask number: 287
# Saved image and mask.
# Processing image and mask number: 288
# Saved image and mask.
# Processing image and mask number: 289
# Saved image and mask.
# Processing image and mask number: 290
# Saved image and mask.
# Processing image and mask number: 291
# Saved image and mask.
# Processing image and mask number: 292
# Saved image and mask.
# Processing image and mask number: 293
# Saved image and mask.
# Processing image and mask number: 294
# Saved image and mask.
# Processing image and mask number: 295
# Saved image and mask.
# Processing image and mask number: 296
# Saved image and mask.
# Processing image and mask number: 297
# Saved image and mask.
# Processing image and mask number: 298
# Saved image and mask.
# Processing image and mask number: 299
# Saved image and mask.
# Processing image and mask number: 300
# Saved image and mask.
# Processing image and mask number: 301
# Saved image and mask.
# Processing image and mask number: 302
# Saved image and mask.
# Processing image and mask number: 303
# Saved image and mask.
# Processing image and mask number: 304
# Saved image and mask.
# Processing image and mask number: 305
# Saved image and mask.
# Processing image and mask number: 306
# Saved image and mask.
# Processing image and mask number: 307
# Saved image and mask.
# Processing image and mask number: 308
# Saved image and mask.
# Processing image and mask number: 309
# Saved image and mask.
# Processing image and mask number: 310
# Saved image and mask.
# Processing image and mask number: 311
# Saved image and mask.
# Processing image and mask number: 312
# Saved image and mask.
# Processing image and mask number: 313
# Skipped due to low non-zero ratio.
# Processing image and mask number: 314
# Saved image and mask.
# Processing image and mask number: 315
# Saved image and mask.
# Processing image and mask number: 316
# Skipped due to low non-zero ratio.
# Processing image and mask number: 317
# Saved image and mask.
# Processing image and mask number: 318
# Saved image and mask.
# Processing image and mask number: 319
# Saved image and mask.
# Processing image and mask number: 320
# Saved image and mask.
# Processing image and mask number: 321
# Saved image and mask.
# Processing image and mask number: 322
# Saved image and mask.
# Processing image and mask number: 323
# Saved image and mask.
# Processing image and mask number: 324
# Skipped due to low non-zero ratio.
# Processing image and mask number: 325
# Saved image and mask.
# Processing image and mask number: 326
# Saved image and mask.
# Processing image and mask number: 327
# Saved image and mask.
# Processing image and mask number: 328
# Saved image and mask.
# Processing image and mask number: 329
# Saved image and mask.
# Processing image and mask number: 330
# Saved image and mask.
# Processing image and mask number: 331
# Saved image and mask.
# Processing image and mask number: 332
# Saved image and mask.
# Processing image and mask number: 333
# Saved image and mask.
# Processing image and mask number: 334
# Saved image and mask.
# Processing image and mask number: 335
# Saved image and mask.
# Processing image and mask number: 336
# Saved image and mask.
# Processing image and mask number: 337
# Saved image and mask.
# Processing image and mask number: 338
# Saved image and mask.
# Processing image and mask number: 339
# Saved image and mask.
# Processing image and mask number: 340
# Skipped due to low non-zero ratio.
# Processing image and mask number: 341
# Saved image and mask.
# Processing image and mask number: 342
# Saved image and mask.
# Processing image and mask number: 343
# Saved image and mask.
# Processing image and mask number: 344
# Saved image and mask.
# Processing image and mask number: 345
# Saved image and mask.
# Processing image and mask number: 346
# Saved image and mask.
# Processing image and mask number: 347
# Saved image and mask.
# Processing image and mask number: 348
# Saved image and mask.
# Processing image and mask number: 349
# Saved image and mask.
# Processing image and mask number: 350
# Saved image and mask.
# Processing image and mask number: 351
# Saved image and mask.
# Processing image and mask number: 352
# Saved image and mask.
# Processing image and mask number: 353
# Saved image and mask.
# Processing image and mask number: 354
# Saved image and mask.
# Processing image and mask number: 355
# Saved image and mask.
# Processing image and mask number: 356
# Saved image and mask.
# Processing image and mask number: 357
# Saved image and mask.
# Processing image and mask number: 358
# Saved image and mask.
# Processing image and mask number: 359
# Saved image and mask.
# Processing image and mask number: 360
# Saved image and mask.
# Processing image and mask number: 361
# Saved image and mask.
# Processing image and mask number: 362
# Saved image and mask.
# Processing image and mask number: 363
# Saved image and mask.
# Processing image and mask number: 364
# Saved image and mask.
# Processing image and mask number: 365
# Saved image and mask.
# Processing image and mask number: 366
# Saved image and mask.
# Processing image and mask number: 367
# Saved image and mask.
# Processing image and mask number: 368
# Saved image and mask.
# Preprocessing complete.
